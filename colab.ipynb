# %%
import zipfile
with zipfile.ZipFile("{path/to/file}", 'r') as zip_ref:
    zip_ref.extractall()

# %%
# !git clone https://github.com/aqx95/Cassava_kaggle.git
% cd /content/Cassava_kaggle

# %%
# !pip install -r requirements.txt
### For training with NFNet
#!pip install git+https://github.com/rwightman/pytorch-image-models.git

# %% [markdown]
# #### Training

# %%
# !python main_2019data.py --epochs 15 --criterion labelsmoothloss --image-size 384 --model-type vit --model-name vit_base_patch16_384
# Out:
# Namespace(criterion='labelsmoothloss', epochs=15, image_size=384, model_name='vit_base_patch16_384', model_type='vit', optimizer='Adam', scheduler='CosineAnnealingWarmRestarts', train_one_fold=False, train_swa=False)
# Image size: 384 x 384
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-vitjx/jx_vit_base_p16_384-83fb41ba.pth" to /root/.cache/torch/hub/checkpoints/jx_vit_base_p16_384-83fb41ba.pth
# Epoch     0: adjusting learning rate of group 0 to 1.0000e-04.
# Fitter Class prepared. Training cuda with SWA: False
#
# Training on Fold 1 with vit_base_patch16_384
#
# 2021-02-18 09-54-46
# LR: 0.0001
#
# Train Steps 1378/1379 summary_loss: 1.209, time: 367.849: 100% 1379/1379 [06:07<00:00,  3.75it/s]
# [RESULT]: Train. Epoch 0 | Avg Train Summary Loss: 1.209263 | Time Elapsed: 00:06:07
#  summary_loss: 1.154,                                    val_acc: 0.871963 time: 51.212: 100% 268/268 [00:51<00:00,  5.24it/s]
# ...

# %%
# % cd ..
# !rm -r rep_0
# Out:
# /content
